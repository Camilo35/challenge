# %%
#Libraries
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine
import psycopg2

# %%
#source
bibliotecas = pd.read_csv(r'C:\Users\Equipo\Desktop\Challenge\src\Bibliotecas populares\-2022-julio\Bibliotecas populares-06-07-2022.csv', sep=',')
museos = pd.read_csv(r'C:\Users\Equipo\Desktop\Challenge\src\Museos\-2022-julio\museos-06-07-2022.csv', sep=',')
salas_cine = pd.read_csv(r'C:\Users\Equipo\Desktop\Challenge\src\Salas de cine\-2022-julio\Salas de cine-06-07-2022.csv', sep=',')

# %%
engine = create_engine('postgresql://postgres:camilo123@localhost:5432/Challenge')

# %%
#selecciona columnas solicitadas
m=museos.iloc[0:,[0,1,2,4,6,7,8,9,11,13,14,15]]

# %%
#renombre columnas
m.columns=(['cod_localidad','id_provincia','id_departamento','categoría','provincia',
       'localidad','nombre','domicilio','código postal','número de teléfono', 'mail','web'
      ])

# %%
#inserta fecha de carga
m.insert(12,'fecha de carga', '07/07/2022', allow_duplicates=False)
m
# Out:
#       cod_localidad  id_provincia  id_departamento  \
# 0           6588100             6             6588
# 1           6077010             6             6077
# 2           6035010             6             6035
# 3           6035010             6             6035
# 4           6049020             6             6049
# ...             ...           ...              ...
# 1177       90098040            90            90098
# 1178       90105080            90            90105
# 1179       90105080            90            90105
# 1180       90105070            90            90105
# 1181       90098040            90            90098
#
#                                categoría     provincia          localidad  \
# 0     Espacios de Exhibición Patrimonial  Buenos Aires         9 de Julio
# 1     Espacios de Exhibición Patrimonial  Buenos Aires          Arrecifes
# 2     Espacios de Exhibición Patrimonial  Buenos Aires         Avellaneda
# ...

# %%
#selecciona columnas solicitadas
biblio = bibliotecas.iloc[0:,[0,1,2,4,6,8,9,10,12,14,15,16]]

# %%
#renombra columnas
biblio.columns=(['cod_localidad','id_provincia','id_departamento','categoría','provincia',
       'localidad','nombre','domicilio','código postal','número de teléfono', 'mail','web'
      ])

# %%
#añade fecha de carga
biblio.insert(12,'fecha de carga', '07/07/2022', allow_duplicates=False)

# %%
biblio
# Out:
#       cod_localidad  id_provincia  id_departamento              categoría  \
# 0          70049060            70            70049  Bibliotecas Populares
# 1           2000010             2             2000  Bibliotecas Populares
# 2           2000010             2             2000  Bibliotecas Populares
# 3           2000010             2             2000  Bibliotecas Populares
# 4           2000010             2             2000  Bibliotecas Populares
# ...             ...           ...              ...                    ...
# 2012       62042560            62            62042  Bibliotecas Populares
# 2013       70028010            70            70028  Bibliotecas Populares
# 2014       62007080            62            62007  Bibliotecas Populares
# 2015       62077010            62            62077  Bibliotecas Populares
# 2016       62042360            62            62042  Bibliotecas Populares
#
#                             provincia                   localidad  \
# ...

# %%
b=biblio.replace('s/d',np.nan)

# %%
#unifica datos
salas=salas_cine.replace('SI','si')
salas=salas_cine.replace('s/d',np.nan)

# %%
#selecciona columnas solicitadas
s=salas.iloc[0:,[0,1,2,4,5,7,8,9,11,13,14,15]]

# %%
#renombra columnas
s.columns=(['cod_localidad','id_provincia','id_departamento','categoría','provincia',
       'localidad','nombre','domicilio','código postal','número de teléfono', 'mail','web'
      ])
s
# Out:
#      cod_localidad  id_provincia  id_departamento      categoría  \
# 0         10049030            10            10049  Salas de cine
# 1         10091150            10            10091  Salas de cine
# 2         22140060            22            22140  Salas de cine
# 3         26091020            26            26091  Salas de cine
# 4         18007010            18            18007  Salas de cine
# ..             ...           ...              ...            ...
# 324        6455030             6             6455  Salas de cine
# 325        6434010             6             6434  Salas de cine
# 326        6791050             6             6791  Salas de cine
# 327       10049030            10            10049  Salas de cine
# 328        6427010             6             6427  Salas de cine
#
#         provincia    localidad                           nombre  \
# 0       Catamarca    Catamarca                     Cinemacenter
# ...

# %%
#agrega fecha de carga
s.insert(12,'fecha de carga', '07/07/2022', allow_duplicates=False)

# %%
#concatena tabla info
info= pd.concat([m, b, s],axis=0)

# %%
#añade Tabla info a postgresql
info.to_sql('info',con=engine,if_exists='replace')
# Out:
# 528

# %%
pd.read_sql("SELECT * FROM info",engine)
# Out:
#       index  cod_localidad  id_provincia  id_departamento  \
# 0         0        6588100             6             6588
# 1         1        6077010             6             6077
# 2         2        6035010             6             6035
# 3         3        6035010             6             6035
# 4         4        6049020             6             6049
# ...     ...            ...           ...              ...
# 3523    324        6455030             6             6455
# 3524    325        6434010             6             6434
# 3525    326        6791050             6             6791
# 3526    327       10049030            10            10049
# 3527    328        6427010             6             6427
#
#                                categoría     provincia   localidad  \
# 0     Espacios de Exhibición Patrimonial  Buenos Aires  9 de Julio
# 1     Espacios de Exhibición Patrimonial  Buenos Aires   Arrecifes
# ...

# %%
#Cantidad de categorías
cantidad_categoria= pd.read_sql("""SELECT categoría AS registro, COUNT(categoría) AS cantidad FROM info GROUP BY categoría""",engine)
cantidad_categoria
# Out:
#                              registro  cantidad
# 0  Espacios de Exhibición Patrimonial      1182
# 1               Bibliotecas Populares      2017
# 2                       Salas de cine       329

# %%
#cantidad de datos por fuente
fuentes= pd.DataFrame([['Bibliotecas Populares',bibliotecas.size],['Museos',museos.size],['Salas de Cine',salas_cine.size]],columns=['registro','cantidad'])
fuentes
# Out:
#                 registro  cantidad
# 0  Bibliotecas Populares     50425
# 1                 Museos     28368
# 2          Salas de Cine      8554

# %%
#Cantidad de salas de cine por provincia
cantidad_categ_prov= pd.read_sql("""SELECT CONCAT(categoría,' / ', provincia) as registro, COUNT(categoría) AS cantidad FROM info GROUP BY categoría, provincia""",engine)
cantidad_categ_prov
# Out:
#                                            registro  cantidad
# 0   Salas de cine / Ciudad Autónoma de Buenos Aires        35
# 1                           Salas de cine / Formosa         2
# 2                 Bibliotecas Populares / Catamarca        38
# 3                          Salas de cine / San Juan         6
# 4                             Salas de cine / Jujuy         4
# ..                                              ...       ...
# 68                    Bibliotecas Populares / Chaco        70
# 69                         Salas de cine / La Pampa         6
# 70    Espacios de Exhibición Patrimonial / Neuquén         39
# 71       Espacios de Exhibición Patrimonial / Salta        36
# 72                         Salas de cine / La Rioja         5
#
# [73 rows x 2 columns]

# %%
#concatenado de cantidad de categorias, guentes y cantidade de categorias por provincias
tabla1= pd.concat([cantidad_categoria, fuentes, cantidad_prov_categ],axis=0)
tabla1
# Out:
#                                          registro  cantidad
# 0              Espacios de Exhibición Patrimonial      1182
# 1                           Bibliotecas Populares      2017
# 2                                   Salas de cine       329
# 0                           Bibliotecas Populares     50425
# 1                                          Museos     28368
# ..                                            ...       ...
# 68                  Bibliotecas Populares / Chaco        70
# 69                       Salas de cine / La Pampa         6
# 70  Espacios de Exhibición Patrimonial / Neuquén         39
# 71     Espacios de Exhibición Patrimonial / Salta        36
# 72                       Salas de cine / La Rioja         5
#
# [79 rows x 2 columns]

# %%
#agrego fecha de carga
tabla1.insert(2,'fecha de carga', '07/07/2022', allow_duplicates=False)
tabla1
# Out:
#                                          registro  cantidad fecha de carga
# 0              Espacios de Exhibición Patrimonial      1182     07/07/2022
# 1                           Bibliotecas Populares      2017     07/07/2022
# 2                                   Salas de cine       329     07/07/2022
# 0                           Bibliotecas Populares     50425     07/07/2022
# 1                                          Museos     28368     07/07/2022
# ..                                            ...       ...            ...
# 68                  Bibliotecas Populares / Chaco        70     07/07/2022
# 69                       Salas de cine / La Pampa         6     07/07/2022
# 70  Espacios de Exhibición Patrimonial / Neuquén         39     07/07/2022
# 71     Espacios de Exhibición Patrimonial / Salta        36     07/07/2022
# 72                       Salas de cine / La Rioja         5     07/07/2022
#
# [79 rows x 3 columns]

# %%
#inserto tabla1 en postgresql
tabla1.to_sql('tabla1',con=engine,if_exists='replace')
# Out:
# 79

# %%
#corrección de valores 
tabla_base=salas_cine.loc[0:,['Provincia','Pantallas', 'Butacas','espacio_INCAA']]
tabla_base=tabla_base.replace('SI',1)
tabla_base=tabla_base.replace('si',1)
tabla_base=tabla_base.replace(np.nan,0)
tabla_base=tabla_base.replace('0',0)

tabla_base
# Out:
#         Provincia  Pantallas  Butacas  espacio_INCAA
# 0       Catamarca          5      743              0
# 1       Catamarca          1      440              0
# 2           Chaco          5      820              0
# 3          Chubut          1       80              0
# 4      Corrientes          1      240              0
# ..            ...        ...      ...            ...
# 324  Buenos Aires          1        0              0
# 325  Buenos Aires          8     2037              0
# 326  Buenos Aires          1      430              1
# 327     Catamarca          1     1103              1
# 328  Buenos Aires          1      390              1
#
# [329 rows x 4 columns]

# %%
#agrupo por provincia  y sumo los datos
tabla2= tabla_base.groupby('Provincia').sum()
tabla2
# Out:
#                                  Pantallas  Butacas  espacio_INCAA
# Provincia
# Buenos Aires                           358    93112             20
# Catamarca                               12     3200              1
# Chaco                                   14     2469              1
# Chubut                                  10     2682              4
# Ciudad Autónoma de Buenos Aires        153    31386              3
# Corrientes                              17     3370              1
# Córdoba                                105    20799              2
# Entre Ríos                              17     4086              2
# Formosa                                  4     1184              1
# Jujuy                                    5     2277              2
# La Pampa                                 6     2071              2
# La Rioja                                10     1477              1
# Mendoza                                 47    11116              2
# ...

# %%
#agrego fecha de carga
tabla2.insert(3,'fecha de carga', '07/07/2022', allow_duplicates=False)
tabla2
# Out:
#                                  Pantallas  Butacas  espacio_INCAA  \
# Provincia
# Buenos Aires                           358    93112             20
# Catamarca                               12     3200              1
# Chaco                                   14     2469              1
# Chubut                                  10     2682              4
# Ciudad Autónoma de Buenos Aires        153    31386              3
# Corrientes                              17     3370              1
# Córdoba                                105    20799              2
# Entre Ríos                              17     4086              2
# Formosa                                  4     1184              1
# Jujuy                                    5     2277              2
# La Pampa                                 6     2071              2
# La Rioja                                10     1477              1
# Mendoza                                 47    11116              2
# ...

# %%
#inserto la tabla en postgresql
tabla2.to_sql('tabla2',con=engine,if_exists='replace')
# Out:
# 24
